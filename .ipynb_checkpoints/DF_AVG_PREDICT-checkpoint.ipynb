# 451  17.641721  17.280685
# 452  16.523138  17.235886
# 453  16.735342  17.040175
# 454  21.996450  16.116312
# 455  21.629487  15.258439
#
# [456 rows x 22 columns]

# %%
class TS_Uni_Models():
    
    def __init__(self,df,future_target,past_history):
        self.df=df
        self.future_target=future_target
        self.past_history=past_history
    
    def univariate_data(self,dataset, start_index, end_index, history_size, target_size):
        data = []
        labels = []
        start_index = start_index + history_size
        if end_index is None:
            end_index = len(dataset) - target_size
        for i in range(start_index, end_index):
            indices = range(i-history_size, i)
            # Reshape data from (history_size,) to (history_size, 1)
            data.append(np.reshape(dataset[indices], (history_size, 1)))
            labels.append(dataset[i+target_size])
        return np.array(data), np.array(labels)
    
    def CalMSE(self,actual,pred):
        return mean_squared_error(actual,pred)
    
    def Univariate_LSTM(self):
        df=self.df
        dataset = df
        len_dataset=len(dataset)
        BATCH_SIZE = 1
        BUFFER_SIZE = 1
        EVALUATION_INTERVAL =len_dataset//BATCH_SIZE
        EPOCHS = 1
        univariate_past_history=self.past_history
        univariate_future_target = self.future_target
        STEP = 1
       
        x_train_uni, y_train_uni = self.univariate_data(uni_data, 0, None,univariate_past_history,univariate_future_target)
        x_val_uni, y_val_uni =x_train_uni[0:1],y_train_uni[0:1]
        x_train_uni,y_train_uni=x_train_uni[1:],y_train_uni[1:]
        train_univariate = tf.data.Dataset.from_tensor_slices((x_train_uni, y_train_uni))
        train_univariate = train_univariate.cache().shuffle(BUFFER_SIZE).batch(BATCH_SIZE).repeat()
        val_univariate = tf.data.Dataset.from_tensor_slices((x_val_uni, y_val_uni))
        val_univariate = val_univariate.batch(BATCH_SIZE).repeat()
        simple_lstm_model = tf.keras.models.Sequential([
        tf.keras.layers.LSTM(32,return_sequences=True,input_shape=x_train_uni.shape[-2:]),
        tf.keras.layers.LSTM(8,activation='relu'),
        tf.keras.layers.Dense(1)
        ])
        simple_lstm_model.compile(optimizer='adam', loss='mae')
        simple_lstm_model.fit(train_univariate, epochs=EPOCHS,steps_per_epoch=EVALUATION_INTERVAL)
        prediction=None
        for x, y in val_univariate.take(1):
            prediction=simple_lstm_model.predict(x)
            y=y.numpy()  
        mse=self.CalMSE(y,prediction)
        return mse,simple_lstm_model
    
    def Univariate_RNN(self):
        df=self.df
        dataset = df
        len_dataset=len(dataset)
        BATCH_SIZE = 1
        BUFFER_SIZE = 1
        EVALUATION_INTERVAL =len_dataset//BATCH_SIZE
        EPOCHS = 1
        univariate_past_history=self.past_history
        univariate_future_target = self.future_target
        STEP = 1
        x_train_uni, y_train_uni = self.univariate_data(uni_data, 0, None,univariate_past_history,univariate_future_target)
        x_val_uni, y_val_uni =x_train_uni[0:1],y_train_uni[0:1]
        x_train_uni,y_train_uni=x_train_uni[1:],y_train_uni[1:]                       
        train_univariate = tf.data.Dataset.from_tensor_slices((x_train_uni, y_train_uni))
        train_univariate = train_univariate.cache().shuffle(BUFFER_SIZE).batch(BATCH_SIZE).repeat()
        val_univariate = tf.data.Dataset.from_tensor_slices((x_val_uni, y_val_uni))
        val_univariate = val_univariate.batch(BATCH_SIZE).repeat()
        simple_lstm_model = tf.keras.models.Sequential([
        tf.keras.layers.SimpleRNN(32,return_sequences=True,input_shape=x_train_uni.shape[-2:]),
        tf.keras.layers.SimpleRNN(8,activation='relu'),
        tf.keras.layers.Dense(1)
        ])
        simple_lstm_model.compile(optimizer='adam', loss='mae')
        simple_lstm_model.fit(train_univariate, epochs=EPOCHS,steps_per_epoch=EVALUATION_INTERVAL)
        prediction=None
        for x, y in val_univariate.take(1):
            prediction=simple_lstm_model.predict(x)
            y=y.numpy()
        mse=self.CalMSE(y,prediction)
        return mse,simple_lstm_model

# %%
uni_data = df['CHW Tout, C']
uni_data.index = df['Date']
print(uni_data)
uni_data = uni_data.values
#uni_data=uni_data[0:200]
uni_data
# Out:
# Date
# 2019-08-25 06:00:00    7.7
# 2019-08-25 05:00:00    7.7
# 2019-08-25 04:00:00    7.7
# 2019-08-25 03:00:00    7.7
# 2019-08-25 02:00:00    7.7
# 2019-08-25 01:00:00    7.7
# 2019-08-25 00:00:00    7.7
# 2019-08-24 23:00:00    7.7
# 2019-08-24 22:00:00    7.7
# 2019-08-24 21:00:00    7.7
# 2019-08-24 20:00:00    7.7
# 2019-08-24 19:00:00    7.7
# 2019-08-24 18:00:00    6.8
# 2019-08-24 17:00:00    6.8
# 2019-08-24 16:00:00    6.8
# 2019-08-24 15:00:00    6.4
# 2019-08-24 14:00:00    6.4
# 2019-08-24 13:00:00    6.4
# 2019-08-24 12:00:00    6.4
# 2019-08-24 11:00:00    6.4
# 2019-08-24 10:00:00    6.8
# 2019-08-24 09:00:00    6.8
# 2019-08-24 08:00:00    7.2
# 2019-08-24 07:00:00    7.2
# Name: CHW Tout, C, dtype: float64
# array([7.7, 7.7, 7.7, 7.7, 7.7, 7.7, 7.7, 7.7, 7.7, 7.7, 7.7, 7.7, 6.8,
#        6.8, 6.8, 6.4, 6.4, 6.4, 6.4, 6.4, 6.8, 6.8, 7.2, 7.2])

# %%
uni_data.shape
# Out:
# (24,)

# %%
univariate_past_history = 10
univariate_future_target = 0

current_data=uni_data[0:univariate_past_history]
uni_data=uni_data[univariate_past_history:]

# %%
uni_train_mean = uni_data.mean()
uni_train_std = uni_data.std()

# %%
uni_data = (uni_data-uni_train_mean)/uni_train_std

# %%
uni_data
# Out:
# array([ 1.94665705,  1.94665705, -0.09733285, -0.09733285, -0.09733285,
#        -1.00577281, -1.00577281, -1.00577281, -1.00577281, -1.00577281,
#        -0.09733285, -0.09733285,  0.81110711,  0.81110711])

# %%
model=TS_Uni_Models(uni_data,univariate_future_target,univariate_past_history)

# %%
mse,modell=model.Univariate_RNN()
# Out:
# Train for 14 steps
# 14/14 [==============================] - 8s 554ms/step - loss: 0.8867

# %%
mse
# Out:
# 1.5993724998112653

# %%
current_data_last=np.reshape(current_data,(1,univariate_past_history,1))

# %%
p=modell.predict(current_data_last)

# %%
p*uni_train_std+uni_train_mean
# Out:
# array([[5.9091544]], dtype=float32)

# %%
current_data=(current_data-uni_train_mean)/uni_train_std
current_data
# Out:
# array([1.94665705, 1.94665705, 1.94665705, 1.94665705, 1.94665705,
#        1.94665705, 1.94665705, 1.94665705, 1.94665705, 1.94665705])

# %%
def make_forecast(model,current_data,multi_step,past_history):
    pred_list=[]
    for _ in range(0,multi_step):
        data_forecast=np.reshape(current_data,(1,past_history,1))
        pred=model.predict(data_forecast)
        pred_list.append(pred)
        current_data=np.insert(current_data, 0, pred)
        current_data=current_data[0:past_history]
        
        
    return pred_list

# %%
pre=make_forecast(modell,current_data,10,univariate_past_history)

# %%
for f in pre:
    print(f[0]*uni_train_std+uni_train_mean)
# Out:
# [5.5913587]
# [5.6768203]
# [5.763621]
# [5.907188]
# [6.1026554]
# [6.2677217]
# [6.6047745]
# [6.65425]
# [6.786691]
# [7.1045856]

# %%
Multi_ModelDic={"Multi_LSTM_model":1,"Multi_RNN_model":2}

# %%
l=list(Multi_ModelDic.keys())
l
# Out:
# ['Multi_LSTM_model', 'Multi_RNN_model']

# %%
Multi_ModelDic['Multi_LSTM_model']
# Out:
# 1

# %%
df.head(20)
# Out:
#               Date Time  p (mbar)  T (degC)  Tpot (K)  Tdew (degC)  rh (%)  \
# 0   01.01.2009 00:10:00    996.52     -8.02    265.40        -8.90    93.3
# 1   01.01.2009 00:20:00    996.57     -8.41    265.01        -9.28    93.4
# 2   01.01.2009 00:30:00    996.53     -8.51    264.91        -9.31    93.9
# 3   01.01.2009 00:40:00    996.51     -8.31    265.12        -9.07    94.2
# 4   01.01.2009 00:50:00    996.51     -8.27    265.15        -9.04    94.1
# 5   01.01.2009 01:00:00    996.50     -8.05    265.38        -8.78    94.4
# 6   01.01.2009 01:10:00    996.50     -7.62    265.81        -8.30    94.8
# 7   01.01.2009 01:20:00    996.50     -7.62    265.81        -8.36    94.4
# 8   01.01.2009 01:30:00    996.50     -7.91    265.52        -8.73    93.8
# 9   01.01.2009 01:40:00    996.53     -8.43    264.99        -9.34    93.1
# 10  01.01.2009 01:50:00    996.62     -8.76    264.66        -9.66    93.1
# 11  01.01.2009 02:00:00    996.62     -8.88    264.54        -9.77    93.2
# 12  01.01.2009 02:10:00    996.63     -8.85    264.57        -9.70    93.5
# 13  01.01.2009 02:20:00    996.74     -8.83    264.58        -9.68    93.5
# 14  01.01.2009 02:30:00    996.81     -8.66    264.74        -9.46    93.9
# 15  01.01.2009 02:40:00    996.81     -8.66    264.74        -9.50    93.6
# 16  01.01.2009 02:50:00    996.86     -8.70    264.70        -9.55    93.5
# 17  01.01.2009 03:00:00    996.84     -8.81    264.59        -9.66    93.5
# 18  01.01.2009 03:10:00    996.87     -8.84    264.56        -9.69    93.5
# 19  01.01.2009 03:20:00    996.97     -8.94    264.45        -9.82    93.3
#
#     VPmax (mbar)  VPact (mbar)  VPdef (mbar)  sh (g/kg)  H2OC (mmol/mol)  \
# 0           3.33          3.11          0.22       1.94             3.12
# 1           3.23          3.02          0.21       1.89             3.03
# 2           3.21          3.01          0.20       1.88             3.02
# 3           3.26          3.07          0.19       1.92             3.08
# 4           3.27          3.08          0.19       1.92             3.09
# 5           3.33          3.14          0.19       1.96             3.15
# 6           3.44          3.26          0.18       2.04             3.27
# 7           3.44          3.25          0.19       2.03             3.26
# 8           3.36          3.15          0.21       1.97             3.16
# 9           3.23          3.00          0.22       1.88             3.02
# 10          3.14          2.93          0.22       1.83             2.94
# 11          3.12          2.90          0.21       1.81             2.91
# 12          3.12          2.92          0.20       1.82             2.93
# 13          3.13          2.92          0.20       1.83             2.93
# 14          3.17          2.98          0.19       1.86             2.99
# 15          3.17          2.97          0.20       1.85             2.98
# 16          3.16          2.95          0.21       1.85             2.96
# 17          3.13          2.93          0.20       1.83             2.94
# 18          3.13          2.92          0.20       1.83             2.93
# 19          3.10          2.89          0.21       1.81             2.90
#
#     rho (g/m**3)  wv (m/s)  max. wv (m/s)  wd (deg)
# 0        1307.75      1.03           1.75     152.3
# 1        1309.80      0.72           1.50     136.1
# 2        1310.24      0.19           0.63     171.6
# 3        1309.19      0.34           0.50     198.0
# 4        1309.00      0.32           0.63     214.3
# 5        1307.86      0.21           0.63     192.7
# 6        1305.68      0.18           0.63     166.5
# 7        1305.69      0.19           0.50     118.6
# 8        1307.17      0.28           0.75     188.5
# 9        1309.85      0.59           0.88     185.0
# 10       1311.64      0.45           0.88     183.2
# 11       1312.25      0.25           0.63     190.3
# 12       1312.11      0.16           0.50     158.3
# 13       1312.15      0.36           0.63     184.8
# 14       1311.37      0.33           0.75     155.9
# 15       1311.38      0.07           0.50     272.4
# 16       1311.64      0.32           0.63     219.2
# 17       1312.18      0.18           0.63     167.2
# 18       1312.37      0.07           0.25     129.3
# 19       1313.01      0.10           0.63     115.3

# %%
w=[[ 1.36752692]
 [ 1.36752692]
 [ 1.36752692]
 [ 1.36752692]
 [ 1.36752692]
 [-0.3760699 ]
 [-0.3760699 ]
 [-0.3760699 ]
 [-1.15100182]
 [-1.15100182]
 [-1.15100182]
 [-1.15100182]
 [-1.15100182]
 [-0.3760699 ]
 [-0.3760699 ]
 [ 0.39886202]
 [ 0.39886]]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-65-93f29a7d06d5> in <module>
#       1 w=[[ 1.36752692]
# ----> 2  [ 1.36752692]
#       3  [ 1.36752692]
#       4  [ 1.36752692]
#       5  [ 1.36752692]
#
# TypeError: list indices must be integers or slices, not float
